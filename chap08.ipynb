# %%
# !pip install langflow

# %%
import os
os.environ['OPENAI_API_KEY'] = ""

# %%
from langflow.load import run_flow_from_json
TWEAKS = {
  "ChatInput-ol1Ok": {},
  "ChatOutput-WlVAo": {},
  "ParseData-wnLJQ": {},
  "File-AOUJv": {},
  "Prompt-ODVjb": {},
  "OpenAIModel-o6HEP": {}
}

result = run_flow_from_json(flow="Document Q&A.json",
                            input_value="How many males died?",
                            session_id="", # provide a session id if you want to use session state
                            fallback_to_env_vars=True, # False by default
                            tweaks=TWEAKS)
print(result)
